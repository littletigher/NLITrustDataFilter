# %%
# !huggingface-cli login
# Out:
# ^C

# %%
from huggingface_hub import HfApi, Repository
import os

# 设置你的 API Token 和其他参数
api_token = r"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"  # 替换为你的 Hugging Face API Token
file_path = r"D:\PycharmProjects\TDFilter\DataSet\Radiation\Radiation.json"  # 替换为你的 JSON 文件路径
repo_name = "ZhJiHo/radiation_domain_dataset"  # 替换为你的 Hugging Face 仓库名称
repo_url = f"https://huggingface.co/{repo_name}"

# 初始化 Hugging Face API
from datasets import load_dataset

# 1. 加载本地 JSON 文件
dataset = load_dataset("json", data_files=file_path)

# 2. 数据处理（添加新列）
# def add_column(example):
#     example["new_column"] = len(example["text"])
#     return example

processed_dataset = dataset

# 3. 推送到 Hugging Face Hub
processed_dataset.push_to_hub(repo_name)

print("处理后的数据集已成功上传到 Hugging Face Hub!")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/78 [00:00<?, ?ba/s]
# 处理后的数据集已成功上传到 Hugging Face Hub!
