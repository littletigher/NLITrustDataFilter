# %%
# !pip install langchain langchain_community langchain_chroma
# Out:
# Requirement already satisfied: langchain in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (0.2.12)
# Requirement already satisfied: langchain_community in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (0.2.11)
# Requirement already satisfied: langchain_chroma in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (0.1.2)
# Requirement already satisfied: numpy<2,>=1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: PyYAML>=5.3 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (2.0.31)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (0.1.85)
# Requirement already satisfied: requests<3,>=2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.27 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (0.2.28)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: pydantic<3,>=1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: fastapi<1,>=0.95.2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain_chroma) (0.111.1)
# Requirement already satisfied: chromadb<0.6.0,>=0.4.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain_chroma) (0.5.4)
# Requirement already satisfied: attrs>=17.3.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (4.1.3)
# Requirement already satisfied: posthog>=2.4.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (3.5.0)
# Requirement already satisfied: orjson>=3.9.12 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (3.10.6)
# Requirement already satisfied: build>=1.0.3 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.2.1)
# Requirement already satisfied: grpcio>=1.58.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.63.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.30.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.19.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.46b0)
# Requirement already satisfied: httpx>=0.27.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.27.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.18.1)
# Requirement already satisfied: mmh3>=4.0.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (4.1.0)
# Requirement already satisfied: tqdm>=4.65.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (4.66.4)
# Requirement already satisfied: pypika>=0.48.9 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.48.9)
# Requirement already satisfied: typer>=0.9.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.12.3)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.25.0)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (30.1.0)
# Requirement already satisfied: importlib-resources in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (6.4.0)
# Requirement already satisfied: overrides>=7.3.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (7.7.0)
# Requirement already satisfied: chroma-hnswlib==0.7.5 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.7.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (4.12.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.25.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: email_validator>=2.0.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from fastapi<1,>=0.95.2->langchain_chroma) (2.2.0)
# Requirement already satisfied: python-multipart>=0.0.7 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from fastapi<1,>=0.95.2->langchain_chroma) (0.0.9)
# Requirement already satisfied: jinja2>=2.11.2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from fastapi<1,>=0.95.2->langchain_chroma) (3.1.4)
# Requirement already satisfied: fastapi-cli>=0.0.2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from fastapi<1,>=0.95.2->langchain_chroma) (0.0.4)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from fastapi<1,>=0.95.2->langchain_chroma) (0.37.2)
# Requirement already satisfied: packaging<25,>=23.2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (24.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (1.33)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: colorama in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain_chroma) (2.0.1)
# Requirement already satisfied: pyproject_hooks in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.1.0)
# Requirement already satisfied: dnspython>=2.0.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from email_validator>=2.0.0->fastapi<1,>=0.95.2->langchain_chroma) (2.6.1)
# Requirement already satisfied: sniffio in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.3.1)
# Requirement already satisfied: anyio in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (4.4.0)
# Requirement already satisfied: httpcore==1.* in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from jinja2>=2.11.2->fastapi<1,>=0.95.2->langchain_chroma) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (2.9.0.post0)
# Requirement already satisfied: oauthlib>=3.2.2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (3.2.2)
# Requirement already satisfied: six>=1.9.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.16.0)
# Requirement already satisfied: requests-oauthlib in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (2.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.8.0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (2.32.0)
# Requirement already satisfied: protobuf in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain_chroma) (4.25.3)
# Requirement already satisfied: coloredlogs in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain_chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain_chroma) (24.3.25)
# Requirement already satisfied: sympy in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.13.0)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (7.1.0)
# Requirement already satisfied: deprecated>=1.2.6 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.2.14)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.25.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.63.2)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.46b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.16.0)
# Requirement already satisfied: setuptools>=16.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (70.3.0)
# Requirement already satisfied: asgiref~=3.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (2.2.1)
# Requirement already satisfied: monotonic>=1.5 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.23.4)
# Requirement already satisfied: click>=8.0.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (8.1.7)
# Requirement already satisfied: rich>=10.11.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (13.7.1)
# Requirement already satisfied: shellingham>=1.3.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: websockets>=10.4 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain_chroma) (12.0)
# Requirement already satisfied: python-dotenv>=0.13 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.22.0)
# Requirement already satisfied: httptools>=0.5.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.6.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (5.3.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (4.9)
# Requirement already satisfied: filelock in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain_chroma) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain_chroma) (2024.5.0)
# Requirement already satisfied: zipp>=0.5 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (3.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (2.18.0)
# Requirement already satisfied: humanfriendly>=9.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain_chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain_chroma) (1.3.0)
# Requirement already satisfied: pyreadline3 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain_chroma) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in d:\pycharmprojects\trustdatafilter\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain_chroma) (0.6.0)
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importing the required libraries
from dotenv import load_dotenv
from dotenv import dotenv_values
import os
load_dotenv(dotenv_path="D:\PycharmProjects\TrustDataFilter\.env")
# Out:
# None

# %%
# Initialize the vectorstore
from langchainMilvusHelper import LangchainMilvusHelper
helper = LangchainMilvusHelper()
vectorstore = helper.get_vector_store()

# %%
question = "What are the approaches to Task Decomposition?"
docs = vectorstore.similarity_search(question)
len(docs)
# Out:
# 4

# %%
docs[0]
# Out:
# Document(metadata={'pk': 451699865353983081, 'summary': 'There are five common dysfunctional co-workers you may encounter .\nTypes: Boss Haters, Stars, Sliders, Pity Parties, and Self-Promoters .\nRefuse to listen to a Boss Hater; steer clear of Pity Parties; turn Slider into a mentor .\nPraise will draw Star back to team but only if you can say it conviction .'}, page_content='(OPRAH.com) -- Her name was Margaret. She had an answer for everything, even questions I didn\'t ask her. She dominated team meetings, nearly jumping out of her chair with "Look at me!"--type comments aimed directly at the boss. There are some tactics to help you survive team destroyers. The rest of us sitting there, jaws slack with amazement and disgust -- we were merely a load she had to carry on her back. His name was Mike, and he hadn\'t done a full day\'s work in years, but he sure knew how to draw us into his life of woe. One night at 10 p.m., I found myself finishing his report on deadline. He couldn\'t be there, he said, because his father was sick. By that point, I wasn\'t even sure he had a father. But there I was, alone, frustrated, and exhausted, in a state of loathing for work so intense I wished I could ditch it all. Oprah.com: The truth about saying no at work . And that is exactly where a dysfunctional co-worker --or as I call them, an "un-teammate" -- can put you. It\'s a crying shame, because working alongside a good team player is one of life\'s most fulfilling experiences. She makes work enjoyable; she makes it feel like something bigger than a paycheck. Working with team destroyers, well, destroys all that. They slow work down; they sap its fun, trust, and creativity. And in the process, they invariably undermine the candid and energized debate that characterizes any successful group. So why aren\'t they all sent packing? In good organizations, most are --eventually. But many team destroyers are like workplace Houdinis, escaping damage to their own careers while making everyone else look bad. These are the people you must survive. But how? The answer depends on the type of un-teammate you\'re dealing with. Generally speaking, there are five: Boss Haters, Stars, Sliders, Pity Parties, and Self-Promoters. Each species has its own way of poisoning the environment and its own antidote. The first thing you can do is start with the assumption that virtually every team destroyer is an unhappy person. No one tries to damage co-workers, a team, or an entire organization without being a bit emotionally damaged themselves. Oprah.com: 6 signs you\'re in the wrong job . Boss haters, stars and sliders . Let\'s start with the boss haters -- you know the type. Harry will tell you his disdain for authority is a reasonable reaction to the tyranny of incompetent bosses. Elizabeth will tell you she refuses to be oppressed by corporate lackeys. Other Boss Haters have personal issues behind their nitpicking resistance to every directive from above. I once met a manager who told me, "For a long time, I hated all my bosses because my father was a cruel authoritarian --I almost ruined my own career. Thank God I came to my senses." Such conversion experiences are rare, however. Most Boss Haters persist, using every kind of subterfuge from eye-rolling to outright belligerence, until management loses patience and ousts them. Some Boss Haters are hard to extricate because of union rules or special skills. If that\'s your situation, your best approach as the peer of a Boss Hater is a freeze-out. Don\'t belabor Harry\'s resistance or try reasoning with Elizabeth. Simply isolate; refuse to listen to their ongoing complaints. Once they\'re cut off from the group, Boss Haters tend to lose their energy. Now for Stars. Make no mistake -- organizations could not survive without their results. Fortunately, many key players are Stars largely because they are the best kind of employee, inclusive and inspiring, but some Stars can develop into real bullies. My team at a con ...
